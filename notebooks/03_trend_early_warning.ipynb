# %% [markdown]
# # 03 · Trend dan early warning
#
# > Fictional Islamic bank, fully synthetic data. Semua logika ada di `src/erm/`; notebook hanya narasi dan visual.

# %%
import sys
from pathlib import Path
ROOT = Path.cwd().parent if Path.cwd().name == "notebooks" else Path.cwd()
sys.path.insert(0, str(ROOT / "src"))
import pandas as pd
from erm import datastore, kri, scoring, validation

# %%
out = datastore.load_outputs()
rs = out['risk_scores_monthly'].pivot(index='period', columns='risk_type', values='final_score')
rs.plot(figsize=(9, 4), title='Final risk score per bulan');

# %%
km = out['kri_monthly']
rep = datastore.reporting_period()
km[(km.period == rep) & ((km.trend_label == 'Deteriorating') | km.early_warning_flag)]
