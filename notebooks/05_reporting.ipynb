# %% [markdown]
# # 05 · Deliverable: Excel, Power BI, executive report
#
# > Fictional Islamic bank, fully synthetic data. Semua logika ada di `src/erm/`; notebook hanya narasi dan visual.

# %%
import sys
from pathlib import Path
ROOT = Path.cwd().parent if Path.cwd().name == "notebooks" else Path.cwd()
sys.path.insert(0, str(ROOT / "src"))
import pandas as pd
from erm import datastore, kri, scoring, validation

# %% [markdown]
# Deliverable dibangun lewat `make report`. Sel berikut membangun ulang dari notebook bila diperlukan.

# %%
from erm import excel_framework, export_powerbi, report
# excel_framework.build(); export_powerbi.export(); report.build()

# %%
out = datastore.load_outputs()
out['management_actions'][['action_id', 'period', 'kri_id', 'severity', 'due_date', 'status']]
# Out:
#   action_id   period kri_id          severity    due_date   status
# 0  ACT-0001  2026-05   OR04  Tolerance breach  2026-06-30   Closed
# 1  ACT-0002  2026-06   CR02  Tolerance breach  2026-07-30  Overdue
# 2  ACT-0003  2026-07   OR04  Tolerance breach  2026-08-30  Overdue
# 3  ACT-0004  2026-07   RR02  Tolerance breach  2026-08-30  Overdue
# 4  ACT-0005  2026-07   ST01  Tolerance breach  2026-08-30  Overdue
# 5  ACT-0006  2026-08   CP02  Tolerance breach  2026-09-30     Open
# 6  ACT-0007  2026-08   OR01  Tolerance breach  2026-09-30     Open
# 7  ACT-0008  2026-08   OR03  Tolerance breach  2026-09-30     Open
# 8  ACT-0009  2026-09   LQ04  Tolerance breach  2026-10-30     Open
# 9  ACT-0010  2026-09   RP01  Tolerance breach  2026-10-30     Open
