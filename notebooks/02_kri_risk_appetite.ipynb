# %% [markdown]
# # 02 · KRI dan risk appetite
#
# > Fictional Islamic bank, fully synthetic data. Semua logika ada di `src/erm/`; notebook hanya narasi dan visual.

# %%
import sys
from pathlib import Path
ROOT = Path.cwd().parent if Path.cwd().name == "notebooks" else Path.cwd()
sys.path.insert(0, str(ROOT / "src"))
import pandas as pd
from erm import datastore, kri, scoring, validation

# %%
out = datastore.load_outputs()
rep = datastore.reporting_period()
scoring.profile_table(out['risk_scores_monthly'], out['enterprise_profile_monthly'], rep)
# Out:
#               risk  score  model            rating  color
# 0           Credit    3.0    NaN          Moderate  Amber
# 1           Market    2.3    NaN   Low to Moderate  Green
# 2        Liquidity    2.7    NaN          Moderate  Amber
# 3      Operational    3.6    NaN  Moderate to High    Red
# 4        Strategic    3.3    NaN          Moderate  Amber
# 5       Compliance    3.6    3.3  Moderate to High    Red
# 6            Legal    2.2    NaN   Low to Moderate  Green
# 7       Reputation    2.6    NaN          Moderate  Amber
# 8   Rate of Return    3.1    NaN          Moderate  Amber
# 9       Investment    2.2    NaN   Low to Moderate  Green
# 10      Enterprise    3.0    NaN          Moderate  Amber

# %%
km = out['kri_monthly']
km[(km.period == rep) & (km.score >= 4)].sort_values('utilization', ascending=False)
# Out:
#       period kri_id       risk_type      value  score              zone color  \
# 475  2026-09   CP02      Compliance   3.000000      4  Tolerance breach   Red
# 479  2026-09   CR02          Credit   5.300000      4  Tolerance breach   Red
# 512  2026-09   ST01       Strategic   7.000000      4  Tolerance breach   Red
# 509  2026-09   RR02  Rate of Return   0.700000      4  Tolerance breach   Red
# 494  2026-09   LQ04       Liquidity  10.500000      4  Tolerance breach   Red
# 499  2026-09   OR01     Operational  21.000000      4  Tolerance breach   Red
# 504  2026-09   RP01      Reputation  25.029940      4  Tolerance breach   Red
# 502  2026-09   OR04     Operational   8.064516      4  Tolerance breach   Red
# 501  2026-09   OR03     Operational   1.600000      4  Tolerance breach   Red
#
#      utilization    trend_label  early_warning_flag
# 475     1.000000  Deteriorating               False
# 479     0.883333         Stable               False
# 512     0.875000  Deteriorating               False
# 509     0.875000  Deteriorating               False
# 494     0.840000  Deteriorating               False
# 499     0.840000  Deteriorating               False
# 504     0.834331  Deteriorating               False
# 502     0.806452  Deteriorating               False
# 501     0.800000  Deteriorating               False
